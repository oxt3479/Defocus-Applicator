# %%
import os
import cv2
import matplotlib.pyplot as plt

image_3 = '/home/oxt3479/dataset_root/data_stereo_flow_multiview/training/image_3/'
directory = os.listdir(image_0)
sample = cv2.imread(image_3 + directory[-1])
plt.imshow(sample)
plt.ylabel('Image Example')
plt.show()
